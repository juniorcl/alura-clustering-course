# %% [markdown]
# # Imports

# %%
import pandas as pd

from mlxtend.preprocessing     import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ## Functions

# %% [markdown]
# # Loading Datasets

# %%
df = pd.read_csv('../data/raw/dados-padaria.csv')

# %%
df.head()
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend

# %%
df.shape
# Out:
# (20507, 5)

# %%
df.isna().mean()
# Out:
# TransactionNo    0.0
# Items            0.0
# DateTime         0.0
# Daypart          0.0
# DayType          0.0
# dtype: float64

# %% [markdown]
# ## Data Preparation

# %%
list_transactions = []

list_unique_transaction = df['TransactionNo'].unique().tolist()

for item in list_unique_transaction:

    set_transaction_item = set(df.loc[df['TransactionNo'] == item, 'Items'])
    
    list_transaction_item = list(set_transaction_item)

    list_transactions.append(list_transaction_item)

# %%
list_transactions
# Out:
# [['Bread'],
#  ['Scandinavian'],
#  ['Jam', 'Cookies', 'Hot chocolate'],
#  ['Muffin'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Pastry', 'Medialuna', 'Muffin'],
#  ['Pastry', 'Tea', 'Medialuna', 'Coffee'],
#  ['Pastry', 'Bread'],
#  ['Bread', 'Muffin'],
#  ['Scandinavian', 'Medialuna'],
#  ['Medialuna', 'Bread'],
#  ['Pastry', 'Tartine', 'Tea', 'Jam', 'Coffee'],
#  ['Basket', 'Bread', 'Coffee'],
#  ['Pastry', 'Medialuna', 'Bread'],
#  ['Mineral water', 'Scandinavian'],
#  ['Medialuna', 'Bread', 'Coffee'],
#  ['Hot chocolate'],
#  ['Farm House'],
#  ['Farm House', 'Bread'],
#  ['Medialuna', 'Bread'],
#  ['Medialuna', 'Bread', 'Coffee'],
#  ['Jam'],
#  ['Scandinavian', 'Muffin'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee'],
#  ['Jam', 'Bread'],
#  ['Bread'],
#  ['Basket'],
#  ['Scandinavian', 'Muffin'],
#  ['Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Scandinavian', 'Muffin'],
#  ['Tea', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Bread'],
#  ['Scandinavian'],
#  ['Juice', 'Tartine', 'Muffin', 'Coffee'],
#  ['Scandinavian'],
#  ['Tea', 'Bread'],
#  ['Scandinavian', 'Fudge'],
#  ['Medialuna', 'Coffee'],
#  ['Medialuna', 'Hot chocolate', 'Coffee'],
#  ['Coffee'],
#  ["Ella's Kitchen Pouches", 'Muffin', 'Juice', 'Jam', 'Bread'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Victorian Sponge', 'Bread'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Coffee', 'Hearty & Seasonal', 'Tea', 'Frittata'],
#  ['Frittata', 'Coffee'],
#  ['Scandinavian'],
#  ['Tea', 'Soup', 'Hot chocolate', 'Victorian Sponge'],
#  ['Tea'],
#  ['Juice', 'Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Smoothies', 'Pick and Mix Bowls', 'Coffee'],
#  ['Coffee'],
#  ['Cake'],
#  ['Tartine', 'Tea', 'Mighty Protein', 'Coffee'],
#  ['Hearty & Seasonal', 'Mineral water', 'Frittata'],
#  ['Hearty & Seasonal', 'Mineral water', 'Muffin'],
#  ['Frittata', 'Tea', 'Chicken sand', 'Scandinavian', 'Coffee'],
#  ['Tea', 'Victorian Sponge', 'Bread'],
#  ['Fudge'],
#  ['Muffin'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Jam', 'Frittata'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Tea', 'Fudge', 'Muffin', 'Coffee'],
#  ['Coffee', 'Bread', 'Frittata'],
#  ['Cake', 'Coffee'],
#  ['Tartine', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Medialuna', 'Coffee'],
#  ['Juice'],
#  ['Bread'],
#  ['Jam', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Tea'],
#  ['Coffee'],
#  ['Coke', 'Bread'],
#  ['Coffee'],
#  ['Farm House', 'Pastry', 'Tea'],
#  ['Pastry', 'Juice', 'Coffee'],
#  ['Pastry', 'Juice', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Bread'],
#  ['Medialuna', 'Muffin', 'Coffee'],
#  ['Tea', 'Cake', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Farm House', 'Muffin'],
#  ['Pastry', 'Bread', 'Muffin'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Cake', 'Coffee'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cake', 'Cookies', 'My-5 Fruit Shoot', 'Coffee'],
#  ['Pastry', 'Tea', 'Cookies'],
#  ['Muffin', 'Coffee'],
#  ['Farm House'],
#  ['Bread', 'Coffee'],
#  ['Cookies'],
#  ['Juice', 'Jam', 'Coffee'],
#  ['Soup', 'Coffee'],
#  ['Tea'],
#  ['Jam', 'Coffee'],
#  ['Farm House'],
#  ['Tartine', 'Tea', 'Coffee'],
#  ['Cake', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Juice', 'Tea', 'Cookies', 'Pick and Mix Bowls'],
#  ['Hearty & Seasonal', 'Soup'],
#  ['Farm House', 'Hearty & Seasonal', 'Tea'],
#  ['Bread'],
#  ['Tea', 'Soup'],
#  ['Farm House'],
#  ['Hearty & Seasonal', 'Soup', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread', 'Muffin'],
#  ['Cookies', 'Coffee'],
#  ['Bread'],
#  ['Tea', 'Muffin'],
#  ['Tea'],
#  ['Hearty & Seasonal', 'Soup'],
#  ['Tea', 'Focaccia', 'Coffee'],
#  ['Sandwich'],
#  ['Tartine', 'Coffee'],
#  ['Fudge', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coke', 'Soup'],
#  ['Muffin'],
#  ['Tea', 'Cookies', 'Muffin', 'Coffee'],
#  ['Hearty & Seasonal', 'Mighty Protein', 'Coke', 'Coffee'],
#  ['Tea', 'Sandwich', 'Muffin'],
#  ['Muffin', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Cookies', 'Hot chocolate', 'Bread'],
#  ['Mineral water', 'Muffin'],
#  ['Tea'],
#  ['Muffin'],
#  ['Juice', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Tea'],
#  ['Muffin', 'Coffee'],
#  ['Hearty & Seasonal', 'Mineral water', 'Sandwich', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Mineral water'],
#  ['Coffee'],
#  ['Tea', 'Soup'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Tea', 'Jam'],
#  ['Tea'],
#  ['Pastry', "Ella's Kitchen Pouches"],
#  ['Pastry'],
#  ['Farm House', 'Tea'],
#  ['Tea', 'Victorian Sponge'],
#  ['Pastry', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Tea', 'Soup'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Scandinavian', 'Bread'],
#  ['Cake', 'Cookies', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Scandinavian', 'Bread'],
#  ['Pastry', 'Coffee'],
#  ['Pastry', 'Scandinavian', 'Coffee'],
#  ['Hearty & Seasonal', 'Muffin', 'Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Soup', 'Coffee'],
#  ['Tartine', 'Cookies', 'Coffee'],
#  ['Bread'],
#  ['Tea', 'Bread'],
#  ['Pastry', 'Coffee'],
#  ['Tartine', 'Coffee'],
#  ['Cookies', 'Bread'],
#  ['Sandwich'],
#  ['Tartine'],
#  ['Pastry', 'Bread'],
#  ['Scandinavian', 'Bread'],
#  ['Scandinavian'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Coke', 'Soup', 'Coffee'],
#  ['Cake'],
#  ['Tea', 'Soup', 'Sandwich'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Alfajores'],
#  ['Cake'],
#  ['Tea', 'Bread'],
#  ['Tea', 'Soup', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Sandwich', 'Coffee'],
#  ['Pastry', 'Tea', 'Cookies', 'Bread'],
#  ['Muffin'],
#  ['Scandinavian'],
#  ['Tea', 'Jam'],
#  ['Juice', 'Tea', 'Alfajores'],
#  ['Coffee', 'Cake', 'Soup', 'Muffin'],
#  ['Cake', 'Hot chocolate', 'Coffee'],
#  ['Cake', 'Cookies'],
#  ['Tea', 'Bread'],
#  ['Juice', 'Alfajores', 'Coffee'],
#  ['Tea', 'Soup', 'Coffee'],
#  ['Hot chocolate'],
#  ['Cookies'],
#  ['Medialuna', 'Coffee'],
#  ['Eggs', 'Bread'],
#  ['Scandinavian'],
#  ['Medialuna'],
#  ['Pastry', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Pastry', 'Hot chocolate', 'Coffee'],
#  ['Coke'],
#  ['Jam', 'Coffee'],
#  ['Tea'],
#  ['Pastry', 'Bread'],
#  ['Farm House', 'Alfajores', 'Coffee'],
#  ['Pastry', 'Tea'],
#  ['Bread'],
#  ['Jam', 'Coffee'],
#  ['Pastry', 'Tea', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Farm House', 'Coffee'],
#  ['Pastry', 'Farm House'],
#  ['Juice', 'Alfajores', 'Bread'],
#  ['Pastry', 'Coffee'],
#  ['Alfajores', 'Bread'],
#  ['Bread'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Cookies'],
#  ['Hearty & Seasonal'],
#  ['Coffee'],
#  ['Tartine', 'Jam', 'Bread'],
#  ['Farm House', 'Scandinavian'],
#  ['Hearty & Seasonal', 'Scandinavian', 'Muffin', 'Coffee'],
#  ['Tartine', 'Coke', 'Pick and Mix Bowls', 'Coffee'],
#  ['Bread'],
#  ['Farm House', 'Scandinavian', 'Alfajores', 'Coffee'],
#  ['Juice', 'Mineral water', 'Soup'],
#  ['Tea', 'Soup'],
#  ['Juice', 'Tea', 'Cookies', 'Soup'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Fudge'],
#  ['Mineral water', 'Soup', 'Juice', 'Coffee'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal', 'Smoothies'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Sandwich', 'Coffee'],
#  ['Farm House', 'Cookies'],
#  ['Juice', 'Tea', 'Soup'],
#  ['Soup'],
#  ['Coffee'],
#  ['Bread'],
#  ['Tea', 'Cookies'],
#  ['Hearty & Seasonal', 'Soup', 'Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Tea'],
#  ['Tea', 'Coffee'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Tea'],
#  ['Tea', 'Soup'],
#  ['Juice'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Alfajores', 'Coffee'],
#  ['Mineral water', 'Alfajores', 'Juice', 'Cookies', 'Pick and Mix Bowls'],
#  ['Alfajores', 'Coffee'],
#  ['Fudge'],
#  ['Juice', 'Mighty Protein'],
#  ['Mineral water', 'Alfajores', 'Coffee'],
#  ['Mighty Protein', 'Coffee'],
#  ['Alfajores'],
#  ['Bread', 'Coffee'],
#  ['Medialuna'],
#  ['Medialuna', 'Bread'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Medialuna'],
#  ['Tea', 'Sandwich', 'Bread'],
#  ['Bread'],
#  ['Farm House', 'Jam', 'Coffee'],
#  ['Focaccia'],
#  ['Bread'],
#  ['Pastry', 'Tartine', 'Bread', 'My-5 Fruit Shoot'],
#  ['Pastry', 'Farm House'],
#  ['Pastry', 'Bread'],
#  ['Pastry', 'Bread'],
#  ['Jam', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Bread'],
#  ['Tea', 'Bread', 'Coffee'],
#  ['Jam'],
#  ['Pastry', 'Medialuna'],
#  ['Coffee'],
#  ['Tea'],
#  ['Bread'],
#  ['Pastry', 'Bread'],
#  ['Pastry'],
#  ['Farm House'],
#  ['Tea'],
#  ['Brownie', 'Fudge', 'Alfajores', 'Coffee'],
#  ['Fudge', 'Cookies', 'Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Pastry', 'Jam', 'Coffee'],
#  ['Soup', 'Coffee'],
#  ['Hearty & Seasonal', 'Smoothies', 'Pastry', 'Soup'],
#  ['Pastry', 'Bread'],
#  ['Pastry', 'Medialuna'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Bread'],
#  ['Hearty & Seasonal',
#   'Sandwich',
#   'Pick and Mix Bowls',
#   'Bread',
#   'Focaccia',
#   'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Sandwich', 'Coffee'],
#  ['Cookies', 'Brownie'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Sandwich', 'Bread', 'Coffee'],
#  ['Hot chocolate', 'Coffee'],
#  ['Tea'],
#  ['Brownie', 'Sandwich', 'Coffee'],
#  ['Pastry', 'Farm House', 'Focaccia', 'Brownie'],
#  ['Cake', 'Focaccia'],
#  ['Hearty & Seasonal', 'Mineral water', 'Soup'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Tea', 'Cake'],
#  ['Soup', 'Coffee'],
#  ['Fudge', 'Bread', 'Focaccia'],
#  ['Alfajores', 'Hot chocolate', 'Coffee'],
#  ['Pastry', 'Cake', 'Brownie'],
#  ['Dulce de Leche', 'Medialuna', 'Alfajores'],
#  ['Dulce de Leche', 'Alfajores'],
#  ['Cake', 'Bread'],
#  ['Cake', 'Coffee'],
#  ['Bread'],
#  ['Sandwich'],
#  ['Medialuna', 'Alfajores', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Alfajores', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Dulce de Leche'],
#  ['Farm House'],
#  ['Fudge'],
#  ['Coffee'],
#  ["Ella's Kitchen Pouches", 'Alfajores', 'Juice', 'Brownie', 'Coffee'],
#  ['Alfajores'],
#  ['Alfajores', 'Juice', 'Brownie', 'Cookies', 'Bread'],
#  ['Cake', 'Cookies'],
#  ['Pick and Mix Bowls'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Tea'],
#  ['Coffee'],
#  ['Farm House', 'Focaccia'],
#  ['Dulce de Leche'],
#  ['Cookies', 'Juice', "Ella's Kitchen Pouches", 'My-5 Fruit Shoot'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Tea', 'Jam', 'Bread'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Medialuna'],
#  ['Jam', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Medialuna', 'Bread'],
#  ['Jam', 'Bread'],
#  ['Jam', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Farm House', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Pastry', 'Tea'],
#  ['Coffee'],
#  ['Bread'],
#  ['Pastry', 'Brownie'],
#  ['Farm House'],
#  ['Coffee'],
#  ['Cookies', 'Tea', 'Honey', 'Coffee'],
#  ['Tea'],
#  ['Bread'],
#  ['Brownie'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Tea'],
#  ['Tea'],
#  ['Coffee'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['The BART', 'Bread'],
#  ['Brownie', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Mineral water', 'Tartine', 'Coffee'],
#  ['Coffee', 'Brownie'],
#  ['Juice', 'Brownie'],
#  ['Pastry', 'Alfajores', 'Tea', 'Medialuna', 'Jam', 'Bread', 'Coffee'],
#  ['Bread'],
#  ['Fudge'],
#  ['Pick and Mix Bowls', 'Coffee'],
#  ['Pastry', 'Bread'],
#  ['Mineral water', 'Scandinavian', 'Soup', 'Coffee'],
#  ['Pick and Mix Bowls', 'Juice', 'Mineral water', 'Sandwich'],
#  ['Pastry', 'Bread'],
#  ['Hearty & Seasonal', 'Coffee'],
#  ['Hearty & Seasonal', 'Mineral water', 'Bread', 'Coffee'],
#  ['Brownie', 'Tartine', 'Sandwich', 'Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Tartine', 'Alfajores', 'Coffee'],
#  ['Mighty Protein', 'Coffee'],
#  ['Hot chocolate', 'Coffee'],
#  ['Jam', 'Soup', 'Coffee'],
#  ['Mineral water', 'Brownie'],
#  ['Scandinavian', 'Coffee'],
#  ['Scandinavian', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Hearty & Seasonal', 'Hot chocolate', 'Coffee'],
#  ['Tea', 'Cake'],
#  ['Medialuna'],
#  ['Tea', 'Alfajores', 'Coffee'],
#  ['Juice', 'Alfajores', 'Brownie', 'Coffee'],
#  ['Sandwich', 'Coffee'],
#  ['Soup', 'Bread'],
#  ['Soup', 'Bread'],
#  ['Bread'],
#  ['Tea', 'Cookies', 'Brownie'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Brownie'],
#  ['Cookies', 'Jam', 'Bread'],
#  ['Coffee'],
#  ['Tea', 'Brownie'],
#  ['Scandinavian', 'Medialuna', 'Alfajores'],
#  ['Cookies', 'Alfajores', 'Hot chocolate', 'Coffee'],
#  ['Brownie'],
#  ['Fudge'],
#  ['Tea', 'Brownie'],
#  ['Fudge', 'Dulce de Leche'],
#  ['Pastry', 'Fudge', 'Scandinavian', 'Bread', 'Granola', 'Coffee'],
#  ['Fudge', 'Bread'],
#  ['Medialuna', 'Hot chocolate', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Bread'],
#  ['Medialuna', 'Jam', 'Bread', 'Coffee'],
#  ['Brownie', 'Jam', 'Coffee'],
#  ['Jam', 'Bread', 'Coffee'],
#  ['Scandinavian'],
#  ['Cookies', 'Coffee'],
#  ['Scandinavian', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee', 'Jam', 'Brownie'],
#  ['Coffee'],
#  ['Hot chocolate', 'Brownie'],
#  ['Bread'],
#  ['Medialuna', 'Bread'],
#  ['Brownie', 'Hot chocolate', 'Coffee'],
#  ['Scandinavian'],
#  ['Basket', 'Bread'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Cake', 'Fudge'],
#  ['Basket', 'Hot chocolate', 'Coffee'],
#  ['Scandinavian'],
#  ['Scandinavian'],
#  ['Cake', 'Medialuna', 'Bread', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Pastry', 'Bread'],
#  ['Bread', 'Brownie'],
#  ['Farm House', 'Medialuna'],
#  ['Medialuna', 'Bread'],
#  ['Smoothies', 'Medialuna', 'Brownie', 'Hot chocolate', 'Coffee'],
#  ['Tea', 'Medialuna', 'Brownie', 'Bread', 'Coffee'],
#  ['Medialuna', 'Cookies'],
#  ['Medialuna', 'Coffee'],
#  ['Fudge', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Coffee'],
#  ['Pastry', 'Bread', 'Brownie'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Coffee', 'Brownie', 'My-5 Fruit Shoot'],
#  ['Fudge', 'Coffee'],
#  ['Coffee'],
#  ['Basket', 'Coffee'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Brownie', 'Coffee'],
#  ['Scandinavian', 'My-5 Fruit Shoot', 'Brownie'],
#  ['Brownie', 'Tartine', 'Hot chocolate', 'Coffee'],
#  ['Hot chocolate', 'Bread', 'Brownie'],
#  ['Fudge', 'Jam'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Hearty & Seasonal', 'Mighty Protein', 'Tea', 'Cake', 'Coffee'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Cake', 'Scandinavian', 'Victorian Sponge'],
#  ['Tea', 'Cake'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Frittata'],
#  ['Brownie', 'My-5 Fruit Shoot', 'Coffee'],
#  ['Fairy Doors', 'Focaccia'],
#  ['Tea', 'Coffee'],
#  ['Pick and Mix Bowls', 'Hearty & Seasonal', 'Hot chocolate', 'Brownie'],
#  ['Coffee', 'Frittata'],
#  ['Bread', 'Brownie'],
#  ['Frittata'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Farm House'],
#  ['Jam', 'Soup', 'Pick and Mix Bowls', 'Brownie'],
#  ['Hearty & Seasonal', 'Tea', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Frittata'],
#  ['Scandinavian'],
#  ['Tartine', 'Hot chocolate', 'Coffee'],
#  ['Mighty Protein', 'Coffee'],
#  ['Coffee', 'Frittata'],
#  ['Scandinavian'],
#  ['Hearty & Seasonal', 'Mineral water', 'Coffee'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee'],
#  ['Hearty & Seasonal', 'Soup', 'Bread', 'Coffee'],
#  ['Cake', 'Tea', 'Brownie'],
#  ['Mighty Protein', 'Coffee'],
#  ['Brownie', 'Tea', 'Soup', 'Coffee'],
#  ['Cake'],
#  ['Cake', 'Hot chocolate', 'Coffee'],
#  ['Hearty & Seasonal', 'Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Brownie', 'Frittata'],
#  ['Mineral water', 'Sandwich', 'Brownie', 'Coke', 'Frittata'],
#  ['Scandinavian', 'Granola'],
#  ['Coke', 'Coffee'],
#  ['Tea', 'Cake', 'Brownie'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Brownie'],
#  ['Cake'],
#  ['Tea'],
#  ['Cake', 'Sandwich', 'Soup', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Coffee', 'Brownie'],
#  ['Brownie', 'Soup', 'Coffee'],
#  ['Fudge'],
#  ['Bread', 'Focaccia'],
#  ['Farm House', 'Jam', 'Bread'],
#  ['Hot chocolate', 'Brownie'],
#  ['Hot chocolate'],
#  ['Brownie', 'Coffee'],
#  ['Pastry', 'Medialuna'],
#  ['Bread'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Mineral water', 'Coffee'],
#  ['Pastry', 'Hot chocolate', 'Bread'],
#  ['Bread'],
#  ['Bread'],
#  ['Jam', 'Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Hearty & Seasonal', 'Focaccia', 'Medialuna', 'Coffee'],
#  ['Farm House', 'Jam', 'Bread', 'Coffee'],
#  ['Farm House'],
#  ['Pastry', 'Tea', 'Medialuna', 'Coffee'],
#  ['Pastry', 'Medialuna', 'Coffee'],
#  ['Basket', 'Farm House', 'Hot chocolate', 'Coffee'],
#  ['Pastry', 'Farm House'],
#  ['My-5 Fruit Shoot', 'Hot chocolate', 'Coffee'],
#  ['Pastry', 'Medialuna', 'Muffin'],
#  ['Farm House'],
#  ['Pastry', 'Focaccia', 'Muffin'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Focaccia'],
#  ['Pastry', 'Jam', 'Hot chocolate', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Tea'],
#  ['Mineral water', 'Hot chocolate', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Jam', 'Coffee'],
#  ['Muffin'],
#  ['Bread'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee', 'Hot chocolate', 'Muffin'],
#  ['Fudge', 'Muffin'],
#  ['Bread'],
#  ['Bread'],
#  ['Farm House'],
#  ['Muffin', 'Coffee'],
#  ['Focaccia'],
#  ['Tea', 'Bread'],
#  ['Hot chocolate', 'Coffee'],
#  ['Jam', 'Tartine', 'Pick and Mix Bowls', 'Coffee'],
#  ['Jam'],
#  ['Tartine'],
#  ['Bread', 'Coffee'],
#  ['Mineral water', 'Juice', 'Tartine', 'Pick and Mix Bowls', 'Coffee'],
#  ['Juice', 'Tea', 'Bread'],
#  ['Cake', 'Coffee'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Coffee', 'Cake', 'Brownie'],
#  ['Coffee', 'Focaccia'],
#  ['Tea', 'Muffin', 'Coffee'],
#  ['Coffee'],
#  ['Tea', 'Coffee'],
#  ['Hearty & Seasonal', 'Cake', 'Coffee'],
#  ['Tea', 'Cake', 'Bread'],
#  ['Mighty Protein', 'Coffee'],
#  ['Hot chocolate', 'Muffin'],
#  ['Mighty Protein', 'Soup', 'Coffee'],
#  ['Jam'],
#  ['Alfajores', 'Coffee'],
#  ['Cake', 'Alfajores', 'Hot chocolate'],
#  ['Tea', 'Hot chocolate', 'Muffin'],
#  ['Brownie'],
#  ['Cake', 'Coffee'],
#  ['Tea', 'Alfajores', 'Victorian Sponge'],
#  ['Bread'],
#  ['Tartine', 'Tea'],
#  ['Mighty Protein', 'Tea'],
#  ['Fudge', 'Bread'],
#  ['Tartine', 'Medialuna', 'Coffee'],
#  ['Pastry', 'Bread'],
#  ['Pastry', 'Bread'],
#  ['Tea', 'Alfajores', 'Coffee'],
#  ['Alfajores', 'Coffee'],
#  ['Alfajores', 'Coffee'],
#  ['Pastry', 'Alfajores'],
#  ['Alfajores'],
#  ['Pastry', 'Tea', 'Alfajores', 'Hearty & Seasonal'],
#  ['Tea', 'Sandwich'],
#  ['Empanadas', 'Tea'],
#  ['Tea', 'Alfajores'],
#  ['Alfajores'],
#  ['Pastry', 'Dulce de Leche'],
#  ['Pastry', 'Coffee'],
#  ['Farm House', 'Coffee'],
#  ['Scandinavian', 'Medialuna', 'Bread'],
#  ['Bread'],
#  ['Pastry', 'Tea', 'Alfajores'],
#  ['Pastry', 'Coffee'],
#  ['Pastry', 'Farm House', 'Bread', 'Muffin'],
#  ['Tea', 'Medialuna'],
#  ['Alfajores'],
#  ['Tea', 'Sandwich'],
#  ['Tea', 'Bread'],
#  ['Pastry', 'Bread', 'Coffee'],
#  ['Empanadas', 'Alfajores', 'Muffin', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Pastry', 'Tea', 'Medialuna', 'Bread'],
#  ['Tea', 'Bread'],
#  ['Muffin'],
#  ['Muffin', 'Coffee'],
#  ['Pastry', 'Medialuna', 'Bread', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Scandinavian', 'Hot chocolate', 'Bread', 'Muffin'],
#  ['Farm House'],
#  ['Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Muffin'],
#  ['Keeping It Local', 'Tea', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Tartine', 'Scandinavian'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Coke', 'Coffee'],
#  ['Muffin', 'Coffee'],
#  ['Muffin', 'Medialuna', 'Scandinavian', 'Bread', 'Coffee'],
#  ['Bread'],
#  ['Coke'],
#  ['Scandinavian', 'Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Scandinavian', 'Bread'],
#  ['Fudge'],
#  ['Hearty & Seasonal', 'Soup', 'Coffee'],
#  ['Coke'],
#  ['Tea', 'Cookies', 'Coffee'],
#  ['Pastry', 'Tea', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Sandwich', 'Soup', 'Muffin', 'Coffee'],
#  ['Tea', 'Muffin', 'Coffee'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Empanadas', 'Scandinavian', 'Bread'],
#  ['Tartine', 'Coffee'],
#  ['Tea'],
#  ['Scandinavian'],
#  ['Muffin'],
#  ['Scandinavian', 'Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Scandinavian', 'Cookies'],
#  ['Empanadas', 'Medialuna', 'Bread', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Tea'],
#  ['Pastry', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Keeping It Local', 'Coffee'],
#  ['Fudge'],
#  ['Tartine', 'Coffee'],
#  ['Pastry', 'Medialuna', 'Hot chocolate', 'Coffee'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Coke'],
#  ['Alfajores', 'Coffee'],
#  ['Muffin'],
#  ['Farm House', 'Fudge', 'Brownie'],
#  ['Coffee'],
#  ['Farm House', 'Tea', 'Muffin'],
#  ['Pastry', 'Coffee'],
#  ['Pastry', 'Brownie'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Pastry', 'Juice', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Tea', 'Alfajores'],
#  ['Alfajores', 'Coffee'],
#  ['Scandinavian'],
#  ['Pastry', 'Medialuna'],
#  ['Brownie'],
#  ['Farm House'],
#  ['Cookies', 'Coffee'],
#  ['Soup'],
#  ['Brownie', 'Art Tray', 'Coffee'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Art Tray', 'Alfajores', 'Soup', 'Frittata'],
#  ['Sandwich', 'Coffee'],
#  ['Tea'],
#  ['Farm House'],
#  ['Scandinavian', 'Muffin'],
#  ['Farm House'],
#  ['Scandinavian'],
#  ['Soup'],
#  ['Hearty & Seasonal', 'Tea', 'Bread'],
#  ['Hot chocolate'],
#  ['Hearty & Seasonal', 'Sandwich', 'Coffee'],
#  ['Coffee', 'Hearty & Seasonal', 'Sandwich', 'Brownie'],
#  ['Medialuna', 'Coffee'],
#  ['Brownie', 'Soup', 'Coffee'],
#  ['Alfajores', 'Sandwich', 'Focaccia'],
#  ['Farm House', 'Tartine'],
#  ['Bread'],
#  ['Coffee'],
#  ['Tea', 'Hot chocolate', 'Muffin'],
#  ['Pastry'],
#  ['Hearty & Seasonal', 'Brownie', 'Soup', 'Bowl Nic Pitt', 'Coffee'],
#  ['Coffee'],
#  ['Farm House', 'Scandinavian', 'Medialuna', 'Alfajores'],
#  ['Soup', 'Coffee'],
#  ['Tea'],
#  ['Tea', 'Cookies', 'Coffee'],
#  ['Tea', 'Muffin'],
#  ['Brownie', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Bread Pudding', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Hot chocolate'],
#  ['Farm House', 'Hot chocolate', 'Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Bread'],
#  ['Hot chocolate', 'Coffee'],
#  ['Bread'],
#  ['Focaccia', 'Medialuna', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Keeping It Local', 'Bread'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Bread'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Tartine', 'Cookies', 'Coffee'],
#  ['Tea', 'Bread'],
#  ['Keeping It Local', 'Bread', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Tea'],
#  ['Juice', 'Coke', 'Soup'],
#  ['Bread'],
#  ['Brownie'],
#  ['Coffee', 'Bread', 'Brownie'],
#  ['Pastry', 'Hearty & Seasonal', 'Bread', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Cookies', 'Bread'],
#  ['Eggs', 'Fudge'],
#  ['Bread'],
#  ['Bread', 'Muffin'],
#  ['Soup'],
#  ['Bread Pudding', 'Coffee'],
#  ['Tartine', 'Bread'],
#  ['Fudge', 'Jam', 'Sandwich', 'Bread Pudding', 'Coffee'],
#  ['Bread Pudding', 'Soup', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Soup', 'Bread', 'Coffee'],
#  ['Tea', 'Soup', 'Focaccia'],
#  ['My-5 Fruit Shoot', 'Cookies', 'Coffee'],
#  ['Coffee'],
#  ['Tea', 'Sandwich', 'Coffee'],
#  ['Scandinavian'],
#  ['Adjustment'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Medialuna', 'Brownie'],
#  ['Pastry', 'Bread', 'Brownie'],
#  ['Pastry', 'Cookies', 'Bread'],
#  ['Bread'],
#  ['Pastry', 'Cookies', 'Juice', 'Coffee'],
#  ['Pastry', 'Cookies', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Tartine', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Cookies', 'Alfajores', 'Bread', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Tea', 'Jam', 'Cookies', 'Bread', 'Keeping It Local', 'Coffee'],
#  ['Pastry', 'Juice', 'Coffee'],
#  ['Medialuna', 'Bread', 'Focaccia'],
#  ['Pastry', 'Medialuna', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Truffles', 'Brownie', 'Cookies', 'Bread', 'Coffee'],
#  ['Tea', 'Art Tray'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cookies', 'Coffee'],
#  ['Brownie'],
#  ['Empanadas', 'Tea', 'Bread'],
#  ['Hot chocolate', 'Bread'],
#  ['Cookies', 'Coffee'],
#  ['Bread'],
#  ['Tartine', 'Tea', 'Sandwich', 'Bread'],
#  ['Sandwich', 'Soup', 'Bread'],
#  ['Soup', 'Bread'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Empanadas', 'Soup', 'Coffee'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Hearty & Seasonal', 'Juice', 'Smoothies', 'Soup', 'Coffee'],
#  ['Alfajores',
#   'Sandwich',
#   'Scandinavian',
#   'Cookies',
#   'Hot chocolate',
#   'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Cookies', 'Bread'],
#  ['Cookies', 'Alfajores', 'Bread'],
#  ['Tea', 'Brownie'],
#  ['Tea', 'Bread'],
#  ['Alfajores', 'Coffee'],
#  ['Bread'],
#  ['Empanadas', 'Coffee'],
#  ['Bread'],
#  ['Hot chocolate', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Coffee'],
#  ['Truffles', 'Tea', 'Hot chocolate', 'Brownie'],
#  ['Keeping It Local', 'Coffee'],
#  ['Coffee'],
#  ['Alfajores'],
#  ['Scandinavian', 'Chimichurri Oil'],
#  ['Truffles', 'Bread'],
#  ['Focaccia', 'Brownie'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Cookies', 'Art Tray', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coke', 'Alfajores', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Pastry', 'Medialuna', 'Bread', 'Coffee'],
#  ['Coffee'],
#  ['Keeping It Local', 'Bread'],
#  ['Bread'],
#  ['Scandinavian', 'Coffee'],
#  ['Pastry', 'Farm House', 'Medialuna', 'Bread'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Farm House', 'Bread'],
#  ['Bread'],
#  ['Keeping It Local', 'Bread'],
#  ...]

# %%
te = TransactionEncoder()

list_transactions_te = te.fit_transform(list_transactions)

# %%
df_transactions = pd.DataFrame(list_transactions_te, columns=te.columns_)
df_transactions
# Out:
#       Adjustment  Afternoon with the baker  Alfajores  Argentina Night  \
# 0          False                     False      False            False
# 1          False                     False      False            False
# 2          False                     False      False            False
# 3          False                     False      False            False
# 4          False                     False      False            False
# ...          ...                       ...        ...              ...
# 9460       False                     False      False            False
# 9461       False                     False      False            False
# 9462       False                     False      False            False
# 9463       False                     False      False            False
# 9464       False                     False      False            False
#
#       Art Tray  Bacon  Baguette  Bakewell  Bare Popcorn  Basket  ...  \
# 0        False  False     False     False         False   False  ...
# 1        False  False     False     False         False   False  ...
# 2        False  False     False     False         False   False  ...
# 3        False  False     False     False         False   False  ...
# 4        False  False     False     False         False   False  ...
# ...        ...    ...       ...       ...           ...     ...  ...
# 9460     False  False     False     False         False   False  ...
# 9461     False  False     False     False         False   False  ...
# 9462     False  False     False     False         False   False  ...
# 9463     False  False     False     False         False   False  ...
# 9464     False  False     False     False         False   False  ...
#
#       The BART  The Nomad  Tiffin  Toast  Truffles  Tshirt  Valentine's card  \
# 0        False      False   False  False     False   False             False
# 1        False      False   False  False     False   False             False
# 2        False      False   False  False     False   False             False
# 3        False      False   False  False     False   False             False
# 4        False      False   False  False     False   False             False
# ...        ...        ...     ...    ...       ...     ...               ...
# 9460     False      False   False  False     False   False             False
# 9461     False      False   False  False      True   False             False
# 9462     False      False   False  False     False   False             False
# 9463     False      False   False  False     False   False             False
# 9464     False      False   False  False     False   False             False
#
#       Vegan Feast  Vegan mincepie  Victorian Sponge
# 0           False           False             False
# 1           False           False             False
# 2           False           False             False
# 3           False           False             False
# 4           False           False             False
# ...           ...             ...               ...
# 9460        False           False             False
# 9461        False           False             False
# 9462        False           False             False
# 9463        False           False             False
# 9464        False           False             False
#
# [9465 rows x 94 columns]

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Association Rules

# %%
df_frequent_items = apriori(df_transactions, use_colnames=True, min_support=0.02)
df_frequent_items.sort_values(['support'], ascending=False)
# Out:
#      support                 itemsets
# 4   0.478394                 (Coffee)
# 1   0.327205                  (Bread)
# 16  0.142631                    (Tea)
# 3   0.103856                   (Cake)
# 20  0.090016          (Bread, Coffee)
# 11  0.086107                 (Pastry)
# 12  0.071844               (Sandwich)
# 9   0.061807              (Medialuna)
# 7   0.058320          (Hot chocolate)
# 23  0.054728           (Cake, Coffee)
# 5   0.054411                (Cookies)
# 31  0.049868            (Tea, Coffee)
# 29  0.047544         (Pastry, Coffee)
# 2   0.040042                (Brownie)
# 6   0.039197             (Farm House)
# 8   0.038563                  (Juice)
# 10  0.038457                 (Muffin)
# 30  0.038246       (Sandwich, Coffee)
# 0   0.036344              (Alfajores)
# 28  0.035182      (Medialuna, Coffee)
# 14  0.034548                  (Scone)
# 15  0.034443                   (Soup)
# 17  0.033597                  (Toast)
# 26  0.029583  (Hot chocolate, Coffee)
# 21  0.029160          (Pastry, Bread)
# 13  0.029054           (Scandinavian)
# 25  0.028209        (Cookies, Coffee)
# 22  0.028104             (Tea, Bread)
# 24  0.023772              (Tea, Cake)
# 32  0.023666          (Toast, Coffee)
# 19  0.023349            (Cake, Bread)
# 27  0.020602          (Juice, Coffee)
# 18  0.020285               (Truffles)

# %%
df_apriori_rules = association_rules(df_frequent_items, metric='confidence', min_threshold=0.5)
df_apriori_rules
# Out:
#        antecedents consequents  antecedent support  consequent support  \
# 0           (Cake)    (Coffee)            0.103856            0.478394
# 1        (Cookies)    (Coffee)            0.054411            0.478394
# 2  (Hot chocolate)    (Coffee)            0.058320            0.478394
# 3          (Juice)    (Coffee)            0.038563            0.478394
# 4      (Medialuna)    (Coffee)            0.061807            0.478394
# 5         (Pastry)    (Coffee)            0.086107            0.478394
# 6       (Sandwich)    (Coffee)            0.071844            0.478394
# 7          (Toast)    (Coffee)            0.033597            0.478394
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.054728    0.526958  1.101515  0.005044    1.102664       0.102840
# 1  0.028209    0.518447  1.083723  0.002179    1.083174       0.081700
# 2  0.029583    0.507246  1.060311  0.001683    1.058553       0.060403
# 3  0.020602    0.534247  1.116750  0.002154    1.119919       0.108738
# 4  0.035182    0.569231  1.189878  0.005614    1.210871       0.170091
# 5  0.047544    0.552147  1.154168  0.006351    1.164682       0.146161
# 6  0.038246    0.532353  1.112792  0.003877    1.115384       0.109205
# 7  0.023666    0.704403  1.472431  0.007593    1.764582       0.332006
